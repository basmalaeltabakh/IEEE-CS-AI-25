# %% [markdown]
# # Cleaning Practice
# Let's first practice handling missing values and duplicate data using the `cancer_data_means.csv` file.

# %%
#import libraries and assign cancer_data_means.csv to a variable 
import pandas as pd
cancer_data = pd.read_csv('cancer_data_means.csv')
cancer_data
# Out:
#            id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0      842302         M   17.99    14.71     122.80  1001.0     0.11840
# 1      842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2    84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3    84348301         M   11.42    20.38      77.58   386.1     0.10070
# 4    84358402         M   20.29    14.34     135.10  1297.0     0.10030
# ..        ...       ...     ...      ...        ...     ...         ...
# 559    926424         M   21.56    22.39     142.00  1479.0     0.11100
# 560    926682         M   20.13    28.25     131.20  1261.0     0.09780
# 561    926954         M   16.60    28.08     108.30   858.1     0.08455
# 562    927241         M   20.60    29.33     140.10  1265.0     0.11780
# 563     92751         B    7.76    24.54      47.92   181.0     0.05263
#
#      compactness  concavity  concave_points  symmetry  fractal_dimension
# 0        0.27760    0.30010         0.14710    0.2419            0.07871
# 1        0.07864    0.08690         0.07017    0.1812            0.05667
# 2        0.15990    0.19740         0.12790    0.2069            0.05999
# 3        0.28390    0.24140         0.10520    0.2597            0.09744
# 4        0.13280    0.19800         0.10430    0.1809            0.05883
# ..           ...        ...             ...       ...                ...
# 559      0.11590    0.24390         0.13890    0.1726            0.05623
# 560      0.10340    0.14400         0.09791    0.1752            0.05533
# 561      0.10230    0.09251         0.05302    0.1590            0.05648
# 562      0.27700    0.35140         0.15200    0.2397            0.07016
# 563      0.04362    0.00000         0.00000    0.1587            0.05884
#
# [564 rows x 12 columns]

# %%
# check which columns have missing values
cancer_data.isnull().sum()
# Out:
# id                   0
# diagnosis            0
# radius               0
# texture              0
# perimeter            0
# area                 0
# smoothness           0
# compactness          0
# concavity            0
# concave_points       0
# symmetry             0
# fractal_dimension    0
# dtype: int64

# %%
# confirm your correction
cancer_data['texture'] = cancer_data['texture'].fillna(cancer_data['texture'].mode()[0])
cancer_data['smoothness'] = cancer_data['smoothness'].fillna(cancer_data['smoothness'].mode()[0])
cancer_data['symmetry'] = cancer_data['symmetry'].fillna(cancer_data['symmetry'].mode()[0])
cancer_data.isnull().sum()
# Out:
# id                   0
# diagnosis            0
# radius               0
# texture              0
# perimeter            0
# area                 0
# smoothness           0
# compactness          0
# concavity            0
# concave_points       0
# symmetry             0
# fractal_dimension    0
# dtype: int64

# %%
# how many duplicates are there ?
cancer_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# drop duplicates
cancer_data = cancer_data.drop_duplicates()

# %%
# confirm correction by rechecking for duplicates in the data
cancer_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Renaming Columns
# Since we also previously changed our dataset to only include means of tumor features, the "_mean" at the end of each feature seems unnecessary. It just takes extra time to type in our analysis later. Rename the columns of the dataframe to remove "_mean".

# %%
# rename the columns of the dataframe (remove _mean from the name of each column if found)
cancer_data.columns =[col.replace('_mean','')for col in cancer_data.columns]

# %%
# display first few rows of the dataframe to confirm changes
cancer_data.head(10)
# Out:
#          id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0    842302         M   17.99    14.71     122.80  1001.0     0.11840
# 1    842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2  84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3  84348301         M   11.42    20.38      77.58   386.1     0.10070
# 4  84358402         M   20.29    14.34     135.10  1297.0     0.10030
# 5    843786         M   12.45    15.70      82.57   477.1     0.12780
# 6    844359         M   18.25    19.98     119.60  1040.0     0.09463
# 7  84458202         M   13.71    20.83      90.20   577.9     0.11890
# 8    844981         M   13.00    21.82      87.50   519.8     0.12730
# 9  84501001         M   12.46    24.04      83.97   475.9     0.11860
#
#    compactness  concavity  concave_points  symmetry  fractal_dimension
# 0      0.27760    0.30010         0.14710    0.2419            0.07871
# 1      0.07864    0.08690         0.07017    0.1812            0.05667
# 2      0.15990    0.19740         0.12790    0.2069            0.05999
# 3      0.28390    0.24140         0.10520    0.2597            0.09744
# 4      0.13280    0.19800         0.10430    0.1809            0.05883
# 5      0.17000    0.15780         0.08089    0.2087            0.07613
# 6      0.10900    0.11270         0.07400    0.1601            0.05742
# 7      0.16450    0.09366         0.05985    0.2196            0.07451
# 8      0.19320    0.18590         0.09353    0.2350            0.07389
# 9      0.23960    0.22730         0.08543    0.2030            0.08243

# %%
# save this for later as a csv file named "cancer_data_edited.csv" and set indexing to false (why ??)
cancer_data.to_csv('cancer_data_means.csv' ,  index = False)

# %% [markdown]
# Why index = false ?
# - عشان المفروض ال index ده رقم الصفوف من 0 to n-1 وده غالبا مش بيكون مهم اننا نرقم الصفوف خصوصا لما نحول الملف ل csv file
