# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
df = pd.read_csv("u.user",sep="|")
df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users =  pd.read_csv("u.user",sep="|")
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
mean_age = users.groupby('occupation')['age'].mean()

mean_age.reset_index()
# Out:
#        occupation        age
# 0   administrator  38.746835
# 1          artist  31.392857
# 2          doctor  43.571429
# 3        educator  42.010526
# 4        engineer  36.388060
# 5   entertainment  29.222222
# 6       executive  38.718750
# 7      healthcare  41.562500
# 8       homemaker  32.571429
# 9          lawyer  36.750000
# 10      librarian  40.000000
# 11      marketing  37.615385
# 12           none  26.555556
# 13          other  34.523810
# 14     programmer  33.121212
# 15        retired  63.071429
# 16       salesman  35.666667
# 17      scientist  35.548387
# 18        student  22.081633
# 19     technician  33.148148
# 20         writer  36.311111

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
gender_count = df.groupby('occupation')['gender'].value_counts().unstack()

gender_count.fillna(0, inplace=True)

gender_count['Male_Ratio'] = gender_count['M'] / (gender_count['M'] + gender_count['F'])


male_ratio_sorted = gender_count['Male_Ratio'].sort_values(ascending=False)

male_ratio_sorted
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: Male_Ratio, dtype: float64

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
age_stats = df.groupby('occupation')['age'].agg(['min', 'max']).reset_index()
age_stats
# Out:
#        occupation  min  max
# 0   administrator   21   70
# 1          artist   19   48
# 2          doctor   28   64
# 3        educator   23   63
# 4        engineer   22   70
# 5   entertainment   15   50
# 6       executive   22   69
# 7      healthcare   22   62
# 8       homemaker   20   50
# 9          lawyer   21   53
# 10      librarian   23   69
# 11      marketing   24   55
# 12           none   11   55
# 13          other   13   64
# 14     programmer   20   63
# 15        retired   51   73
# 16       salesman   18   66
# 17      scientist   23   55
# 18        student    7   42
# 19     technician   21   55
# 20         writer   18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
mean_age_per_group = df.groupby(['occupation', 'gender'])['age'].mean().reset_index()


mean_age_per_group.sort_values(by=['occupation', 'gender'], inplace=True)


mean_age_per_group
# Out:
#        occupation gender        age
# 0   administrator      F  40.638889
# 1   administrator      M  37.162791
# 2          artist      F  30.307692
# 3          artist      M  32.333333
# 4          doctor      M  43.571429
# 5        educator      F  39.115385
# 6        educator      M  43.101449
# 7        engineer      F  29.500000
# 8        engineer      M  36.600000
# 9   entertainment      F  31.000000
# 10  entertainment      M  29.000000
# 11      executive      F  44.000000
# 12      executive      M  38.172414
# 13     healthcare      F  39.818182
# 14     healthcare      M  45.400000
# 15      homemaker      F  34.166667
# 16      homemaker      M  23.000000
# 17         lawyer      F  39.500000
# 18         lawyer      M  36.200000
# 19      librarian      F  40.000000
# 20      librarian      M  40.000000
# 21      marketing      F  37.200000
# 22      marketing      M  37.875000
# 23           none      F  36.500000
# 24           none      M  18.600000
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
occupation_counts = df['occupation'].value_counts()


gender_counts = df.groupby(['occupation', 'gender']).size().unstack(fill_value=0)

gender_percentage = (gender_counts.div(occupation_counts, axis=0) * 100).reset_index()


gender_percentage.columns = ['occupation', 'Female_Percentage', 'Male_Percentage']

gender_percentage
# Out:
#        occupation  Female_Percentage  Male_Percentage
# 0   administrator          45.569620        54.430380
# 1          artist          46.428571        53.571429
# 2          doctor           0.000000       100.000000
# 3        educator          27.368421        72.631579
# 4        engineer           2.985075        97.014925
# 5   entertainment          11.111111        88.888889
# 6       executive           9.375000        90.625000
# 7      healthcare          68.750000        31.250000
# 8       homemaker          85.714286        14.285714
# 9          lawyer          16.666667        83.333333
# 10      librarian          56.862745        43.137255
# 11      marketing          38.461538        61.538462
# 12           none          44.444444        55.555556
# 13          other          34.285714        65.714286
# 14     programmer           9.090909        90.909091
# 15        retired           7.142857        92.857143
# ...
