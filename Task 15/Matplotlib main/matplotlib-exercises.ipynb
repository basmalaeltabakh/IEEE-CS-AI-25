# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [Matplotlib documentation](https://matplotlib.org/3.1.1/contents.html).
#
# If you're stuck, don't forget, you can always search for a function, for example if you want to create a plot with `plt.subplots()`, search for [`plt.subplots()`](https://www.google.com/search?q=plt.subplots()).

# %%
# Import the pyplot module from matplotlib as plt and make sure 
# plots appear in the notebook using '%matplotlib inline'
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Create a simple plot using plt.plot()

X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(X, y, marker='o', linestyle='-', color='b')

plt.title('Simple Line Plot')
plt.xlabel('X Values')
plt.ylabel('Y Values')


plt.show()

# %%
# Plot a single Python list
y = [10, 20, 15, 30, 25]

# Plot (x-values are auto-generated as 0, 1, 2, 3, 4)
plt.plot(y, marker='o', linestyle='-', color='blue')

plt.title('Single List Plot')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them

X = [5, 10, 15, 20, 25]
y = [100, 200, 150, 300, 250]

# %%
# Plot X & y (the lists you've created)
plt.plot(X, y, marker='s', linestyle='--', color='g')

plt.title('Line Plot with Custom Values')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.grid(True)

plt.show()

# %% [markdown]
# There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()

fig, ax = plt.subplots()

ax.plot(X, y, color='purple', marker='x')
ax.set_title('Subplot with plt.subplots()')
ax.set_xlabel('X Values')
ax.set_ylabel('Y Values')



plt.show()

# %%
# Create a plot using plt.subplots() and then add X & y on the axes

fig, ax = plt.subplots()


ax.plot(X, y, color='purple')

# Customize
ax.set_title('Subplot with plt.subplots()')
ax.set_xlabel('X Values')
ax.set_ylabel('Y Values')
ax.grid(True)

# Display
plt.show()

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready
import matplotlib.pyplot as plt

# Prepare data (create two lists of 5 numbers, X & y)
X = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# Setup figure and axes using plt.subplots()
fig, ax = plt.subplots()

# Add data (X, y) to axes
ax.plot(X, y, marker='o', linestyle='-', color='green', label='Data Line')

# Customize plot by adding a title, xlabel, and ylabel
ax.set_title('Sample Line Plot')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.legend()
ax.grid(True)

# Save the plot to a file using fig.savefig()
fig.savefig('sample_plot.png')

plt.show()

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
# Import NumPy as np
import numpy as np

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
x =np.linspace(0,100,100)
print(x)
# Out:
# [  0.           1.01010101   2.02020202   3.03030303   4.04040404
#    5.05050505   6.06060606   7.07070707   8.08080808   9.09090909
#   10.1010101   11.11111111  12.12121212  13.13131313  14.14141414
#   15.15151515  16.16161616  17.17171717  18.18181818  19.19191919
#   20.2020202   21.21212121  22.22222222  23.23232323  24.24242424
#   25.25252525  26.26262626  27.27272727  28.28282828  29.29292929
#   30.3030303   31.31313131  32.32323232  33.33333333  34.34343434
#   35.35353535  36.36363636  37.37373737  38.38383838  39.39393939
#   40.4040404   41.41414141  42.42424242  43.43434343  44.44444444
#   45.45454545  46.46464646  47.47474747  48.48484848  49.49494949
#   50.50505051  51.51515152  52.52525253  53.53535354  54.54545455
#   55.55555556  56.56565657  57.57575758  58.58585859  59.5959596
#   60.60606061  61.61616162  62.62626263  63.63636364  64.64646465
#   65.65656566  66.66666667  67.67676768  68.68686869  69.6969697
#   70.70707071  71.71717172  72.72727273  73.73737374  74.74747475
#   75.75757576  76.76767677  77.77777778  78.78787879  79.7979798
#   80.80808081  81.81818182  82.82828283  83.83838384  84.84848485
#   85.85858586  86.86868687  87.87878788  88.88888889  89.8989899
#   90.90909091  91.91919192  92.92929293  93.93939394  94.94949495
#   95.95959596  96.96969697  97.97979798  98.98989899 100.        ]

# %%
# Create a plot using plt.subplots() and plot X versus X^2 (X squared)

X = np.linspace(0, 100, 100)

fig, ax = plt.subplots()

# Plot X versus X^2
ax.plot(X, X**2)


ax.set_title("Plot of X vs X^2")
ax.set_xlabel("X")
ax.set_ylabel("X^2")


plt.show()

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))
X = np.linspace(0, 5, 100)

fig, ax = plt.subplots()
ax.scatter(X, np.exp(X), color='green', marker='o')
ax.set_title("Scatter Plot of X vs exp(X)")
ax.set_xlabel("X")
ax.set_ylabel("exp(X)")


plt.show()

# %%
# Create a scatter plot of X versus np.sin(X)

X = np.linspace(0, 5, 100)
fig, ax = plt.subplots()

ax.scatter(X, np.sin(X), color='green', marker='o')

ax.set_title("Scatter Plot of X vs sin(X)")
ax.set_ylabel("sin(X)")
ax.set_xlabel("X")


plt.show()

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with 
# The keys of the dictionary should be the food name and the values their price
favorite_foods = {
    "Pizza": 120,
    "Sushi": 150,
    "Burger": 80
}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary
favorite_foods = {
    "Pizza": 120,
    "Sushi": 150,
    "Burger": 80
}

plt.bar(favorite_foods.keys(), favorite_foods.values(), color='skyblue')
plt.title("Prices of My Favorite Foods")
plt.xlabel("Food Name")
plt.ylabel("Price (Currency)")
plt.show()

# %%
# Make the same plot as above, except this time make the bars go horizontal
favorite_foods = {
    "Pizza": 120,
    "Sushi": 150,
    "Burger": 80
}

plt.barh(favorite_foods.keys(), favorite_foods.values(), color='skyblue')
plt.title("Prices of My Favorite Foods")
plt.ylabel("Food Name")
plt.xlabel("Price (Currency)")
plt.show()

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X
X = np.random.randn(1000)
# Create a histogram plot of X
plt.hist(X, bins=30, color='lightblue', edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# Create a NumPy array of 1000 random numbers and save it to X
X = np.random.rand(1000)

# Create a histogram plot of X
plt.hist(X, bins=30, color='lightgreen', edgecolor='black')
plt.title("Histogram of Randomly Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
# What else can you find out about the normal distribution?
#
# Can you think of any other kinds of data which may be normally distributed?
#
# These questions aren't directly related to plotting or Matplotlib but they're helpful to think of.
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
fig, axes = plt.subplots(2, 2, figsize=(8, 6))

fig.suptitle("2x2 Empty Subplots")
plt.show()

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
X = np.linspace(0, 10, 100)

# Random data for the scatter plot
scatter_x = np.random.rand(10)
scatter_y = np.random.rand(10)

# Data for the bar plot (favourite food and prices)
favourite_food = {
    "Pizza": 50,
    "Burger": 30,
    "Pasta": 40
}

# Data for the histogram (normally distributed random numbers)
normal_dist_data = np.random.randn(1000)

# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)
fig, axes = plt.subplots(2, 2, figsize=(10, 5))
fig.suptitle("Multi-Plot Visualization", fontsize=14)

# Plot X versus X/2 on the top left axes
axes[0, 0].plot(X, X / 2, color='blue')
axes[0, 0].set_title("X vs X/2")
axes[0, 0].set_xlabel("X")
axes[0, 0].set_ylabel("X/2")

# Plot a scatter plot of 10 random numbers on each axis on the top right subplot
axes[0, 1].scatter(scatter_x, scatter_y, color='red')
axes[0, 1].set_title("Random Scatter Plot")
axes[0, 1].set_xlabel("Random X")
axes[0, 1].set_ylabel("Random Y")

# Plot a bar graph of the favourite food keys and values on the bottom left subplot
axes[1, 0].bar(favourite_food.keys(), favourite_food.values(), color='orange')
axes[1, 0].set_title("Favourite Food Prices")
axes[1, 0].set_xlabel("Food")
axes[1, 0].set_ylabel("Price ($)")

# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
axes[1, 1].hist(normal_dist_data, bins=30, color='lightgreen', edgecolor='black')
axes[1, 1].set_title("Histogram of Normal Distribution")
axes[1, 1].set_xlabel("Value")
axes[1, 1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# Woah. There's a lot going on there.
#
# Now we've seen how to plot with Matplotlib and data directly. Let's practice using Matplotlib to plot with pandas.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
# Import pandas as pd
import pandas as pd

# %%
# Import the '../data/car-sales.csv' into a DataFame called car_sales and view
cars = pd.read_csv('car-sales.csv')
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Try to plot the 'Price' column using the plot() function
cars['Price'].plot(kind='line', marker='o', color='blue', linestyle='--')
plt.title("Price Plot")
plt.xlabel("Index")
plt.ylabel("Price ($)")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Try to plot the 'Price' column using the plot() function
# ----> 2 cars['Price'].plot(kind='line', marker='o', color='blue', linestyle='--')
#       3 plt.title("Price Plot")
#       4 plt.xlabel("Index")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\plotting\_matplotlib\core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
cars['Price'] = cars['Price'].str.replace(r'[\$,]', '', regex=True).astype(float)

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column

cars['Total Sales'] = cars['Price'].cumsum()
# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)
cars['Sale Date'] = pd.date_range(start=pd.Timestamp.today(), periods=len(cars))
# View the car_sales DataFrame
cars
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales  \
# 0  Toyota  White         150043      4   4000.0       4000.0
# 1   Honda    Red          87899      4   5000.0       9000.0
# 2  Toyota   Blue          32549      3   7000.0      16000.0
# 3     BMW  Black          11179      5  22000.0      38000.0
# 4  Nissan  White         213095      4   3500.0      41500.0
# 5  Toyota  Green          99213      4   4500.0      46000.0
# 6   Honda   Blue          45698      4   7500.0      53500.0
# 7   Honda   Blue          54738      4   7000.0      60500.0
# 8  Toyota  White          60000      4   6250.0      66750.0
# 9  Nissan  White          31600      4   9700.0      76450.0
#
#                    Sale Date
# 0 2025-05-16 20:09:21.543377
# 1 2025-05-17 20:09:21.543377
# 2 2025-05-18 20:09:21.543377
# 3 2025-05-19 20:09:21.543377
# 4 2025-05-20 20:09:21.543377
# 5 2025-05-21 20:09:21.543377
# 6 2025-05-22 20:09:21.543377
# 7 2025-05-23 20:09:21.543377
# 8 2025-05-24 20:09:21.543377
# 9 2025-05-25 20:09:21.543377

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column
plt.figure(figsize=(12, 5))
plt.plot(cars['Sale Date'], cars['Total Sales'], marker='o', linestyle='-', color='green')
plt.title("Total Sales Over Time")
plt.xlabel("Sale Date")
plt.ylabel("Total Sales ($)")
plt.grid(True)
plt.show()

# %%
# Convert the 'Price' column to the integers
cars['Price'] = cars['Price'].astype(int)

# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function
plt.figure(figsize=(8,5))
plt.plot(cars['Odometer (KM)'], cars['Price'], 'o', color='blue')  
plt.title('Scatter Plot of Odometer (KM) vs Price')
plt.xlabel('Odometer (KM)')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Create a NumPy array of random numbers of size (10, 4)
X = np.random.rand(10, 4)

# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']
df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])

# Create a bar graph of the DataFrame
df.plot(kind='bar', figsize=(10, 6))
plt.title("Bar Graph of DataFrame Columns")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the cars DataFrame
cars.plot(kind='bar', x='Make', y='Odometer (KM)', figsize=(10,6), color='skyblue')
plt.title('Odometer (KM) by Car Make')
plt.xlabel('Make')
plt.ylabel('Odometer (KM)')
plt.xticks(rotation=45) 
plt.tight_layout()
plt.show()

# %%
# Create a histogram of the 'Odometer (KM)' column
plt.figure(figsize=(8,5))
plt.hist(cars['Odometer (KM)'], bins=20, color='green', edgecolor='black')
plt.title('Histogram of Odometer (KM)')
plt.xlabel('Odometer (KM)')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a histogram of the 'Price' column with 20 bins

plt.figure(figsize=(8,5))
plt.hist(cars['Price'], bins=20, color='teal', edgecolor='black')
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Now we've seen a few examples of plotting directly from DataFrames using the `car_sales` dataset.
#
# Let's try using a different dataset.

# %%
# Import "../data/heart-disease.csv" and save it to the variable "heart_disease"
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# View the first 10 rows of the heart_disease DataFrame
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
# Create a histogram of the "age" column with 50 bins
plt.figure(figsize=(8,5))
plt.hist(heart_disease['age'], bins=50, color='purple', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Call plot.hist() on the heart_disease DataFrame and toggle the
# "subplots" parameter to True
heart_disease.plot.hist(subplots=True, figsize=(16, 12), bins=20, layout=(4, 4), alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# That plot looks pretty squished. Let's change the figsize.

# %%
# Call the same line of code from above except change the "figsize" parameter
# to be (10, 30)
heart_disease.plot.hist(subplots=True, figsize=(10, 30), bins=20, layout=(4, 4), alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's try comparing two variables versus the target variable.
#
# More specifially we'll see how age and cholesterol combined effect the target in **patients over 50 years old**.
#
# For this next challenge, we're going to be replicating the following plot:
#
# <img src="../images/matplotlib-heart-disease-chol-age-plot.png"/>

# %%
heart_disease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Replicate the above plot in whichever way you see fit

# Note: The method below is only one way of doing it, yours might be
# slightly different

# Create DataFrame with patients over 50 years old
over_50 = heart_disease[heart_disease['age'] > 50]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
colors = {0: 'blue', 1: 'red'}
for target_value in over_50['target'].unique():
    subset = over_50[over_50['target'] == target_value]
    ax.scatter(subset['age'], subset['chol'],
               label=f"Target = {target_value}",
               alpha=0.7,
               c=colors[target_value])


# Customize the plot
ax.set_title('Cholesterol vs Age for Patients Over 50')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.legend()
ax.grid(True)

# Add a meanline
mean_chol = over_50['chol'].mean()
ax.axhline(mean_chol, color='green', linestyle='--', label=f'Mean Cholesterol: {mean_chol:.1f}')
ax.legend()

plt.show()

# %% [markdown]
# Beatiful, now you've created a plot of two different variables, let's change the style.

# %%
# Check what styles are available under plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Change the style to use "seaborn-whitegrid"

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# Now the style has been changed, we'll replot the same figure from above and see what it looks like.
#
# If you've changed the style correctly, it should look like the following:
# <img src="../images/matplotlib-heart-disease-chol-age-plot-seaborn-whitegrid.png"/>

# %%
# Reproduce the same figure as above with the "seaborn-whitegrid" style
plt.style.use('seaborn-v0_8-whitegrid')
# Create DataFrame with patients over 50 years old
over_50 = heart_disease[heart_disease['age'] > 50]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
colors = {0: 'blue', 1: 'red'}
for target_value in over_50['target'].unique():
    subset = over_50[over_50['target'] == target_value]
    ax.scatter(subset['age'], subset['chol'],
               label=f"Target = {target_value}",
               alpha=0.7,
               c=colors[target_value])


# Customize the plot
ax.set_title('Cholesterol vs Age for Patients Over 50')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.legend()
ax.grid(True)

# Add a meanline
mean_chol = over_50['chol'].mean()
ax.axhline(mean_chol, color='green', linestyle='--', label=f'Mean Cholesterol: {mean_chol:.1f}')
ax.legend()

plt.show()

# %% [markdown]
# Wonderful, you've changed the style of the plots and the figure is looking different but the dots aren't a very good colour.
#
# Let's change the `cmap` parameter of `scatter()` as well as the `color` parameter of `axhline()` to fix it.
#
# Completing this step correctly should result in a figure which looks like this:
# <img src="../images/matplotlib-heart-disease-chol-age-plot-cmap-change.png"/>

# %%
# Replot the same figure as above except change the "cmap" parameter
# of scatter() to "winter"
# Also change the "color" parameter of axhline() to "red"
plt.style.use('seaborn-v0_8-whitegrid')
# Create DataFrame with patients over 50 years old
over_50 = heart_disease[heart_disease['age'] > 50]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data with cmap="winter" instead of individual colors
scatter = ax.scatter(over_50['age'], over_50['chol'], 
                     c=over_50['target'], cmap='winter', alpha=0.7, label='Patients')

# Customize the plot
ax.set_title('Cholesterol vs Age for Patients Over 50')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.legend(*scatter.legend_elements(), title="Target")
ax.grid(True)

# Add a meanline with color red
mean_chol = over_50['chol'].mean()
ax.axhline(mean_chol, color='red', linestyle='--', label=f'Mean Cholesterol: {mean_chol:.1f}')
ax.legend()

plt.show()

# %% [markdown]
# Beautiful! Now our figure has an upgraded color scheme let's save it to file.

# %%
# Save the current figure using savefig(), the file name can be anything you want

plt.savefig('cholesterol_vs_age_plot.png', dpi=300, bbox_inches='tight')

# %%
# Reset the figure by calling plt.subplots()
fig, ax = plt.subplots()

# %% [markdown]
# ## Extensions
#
# For more exercises, check out the [Matplotlib tutorials page](https://matplotlib.org/3.1.1/tutorials/index.html). A good practice would be to read through it and for the parts you find interesting, add them into the end of this notebook.
#
# The next place you could go is the [Stack Overflow page for the top questions and answers for Matplotlib](https://stackoverflow.com/questions/tagged/matplotlib?sort=MostVotes&edited=true). Often, you'll find some of the most common and useful Matplotlib functions here. Don't forget to play around with the Stack Overflow filters! You'll likely find something helpful here.
#
# Finally, as always, remember, the best way to learn something new is to try it. And try it relentlessly. Always be asking yourself, "is there a better way this data could be visualized so it's easier to understand?"
